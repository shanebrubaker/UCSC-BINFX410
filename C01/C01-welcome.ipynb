# %%
# C01-Welcome

# %%
## Welcome Notebook for Bioinformatics BINF.X410 ##

# %%
# Make sure ipython is up to date
! pip install --upgrade ipython

# %%
print ("Welcome to Class!")

# %%
# Run a terminal command 
! ls

# %%
# Line-level magic example
# %timeit L = [n ** 2 for n in range(1000)]

# %%
# %%writefile my_script.py
def greet(name):
    print(f"Hello, {name}!")
# you cannot put a comment directly above a cell magic

# %%
# %%bash
# echo "Testing cell magics"

# %%
## End of Notebook ##
